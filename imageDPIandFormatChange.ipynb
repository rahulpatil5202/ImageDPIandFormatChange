# %%
import os
import time

# %%
root_folder = input('Enter root folder path to process jpg images:')
# Out:
# Enter root folder path to process jpg images:E:\image_conversion_lot1

# %%
print("\n\nProcessing from root folder " + str(root_folder) + "\n\n")
time.sleep(3)
# Out:
# Processing from root folder E:\image_conversion_lot1

# %%
from PIL import Image

def changeDPIandFormat(file_name):
    im = Image.open(file_name)
    #print(im.info)  # {'dpi': (96, 96), 'gamma': 0.45455}
    #nx, ny = im.size
    #im.resize((int(nx*1), int(ny*1)), Image.BICUBIC)
    dir_name,fl_name = os.path.split(file_name)
    pdf_name = str(os.path.splitext(fl_name)[0]) + ".pdf"
    tiff_name = str(os.path.splitext(fl_name)[0]) + ".tiff"
    pdf_path = os.path.join(dir_name,pdf_name)
    tiff_path = os.path.join(dir_name, tiff_name)
    im.save(pdf_path, dpi=(50,50))
    print("Saved "+str(pdf_path)+" in 50 DPI")
    im.save(tiff_path, dpi=(300,300), compression="jpeg", quality=100)
    print("Saved "+str(tiff_path)+" in 300 DPI")
    print("\n\n")

# %%
def combineInTiff(jpg_list):

# %%
all_jpgs = []

# %%
for root, dirs, files in os.walk(root_folder):
    for file in files:
        if file.endswith(".jpg"):
             all_jpgs.append(os.path.join(root, file))

# %%
for cntr,jpg_img in enumerate(all_jpgs):
    print("\n\n")
    print("Processing "+str(cntr+1)+" of "+str(len(all_jpgs)))
    print(str(jpg_img))
    changeDPIandFormat(jpg_img)
print("Processing Done...\n")
# Out:
# Processing 1 of 54
# E:\image_conversion_lot1\A.jpg
# Saved E:\image_conversion_lot1\A.pdf in 50 DPI
# Saved E:\image_conversion_lot1\A.tiff in 300 DPI
#
#
#
#
#
#
# Processing 2 of 54
# E:\image_conversion_lot1\B.jpg
# Saved E:\image_conversion_lot1\B.pdf in 50 DPI
# Saved E:\image_conversion_lot1\B.tiff in 300 DPI
#
#
#
#
#
#
# Processing 3 of 54
# E:\image_conversion_lot1\image00001.jpg
# Saved E:\image_conversion_lot1\image00001.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00001.tiff in 300 DPI
#
#
#
#
#
#
# Processing 4 of 54
# E:\image_conversion_lot1\image00002.jpg
# Saved E:\image_conversion_lot1\image00002.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00002.tiff in 300 DPI
#
#
#
#
#
#
# Processing 5 of 54
# E:\image_conversion_lot1\image00003.jpg
# Saved E:\image_conversion_lot1\image00003.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00003.tiff in 300 DPI
#
#
#
#
#
#
# Processing 6 of 54
# E:\image_conversion_lot1\image00004.jpg
# Saved E:\image_conversion_lot1\image00004.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00004.tiff in 300 DPI
#
#
#
#
#
#
# Processing 7 of 54
# E:\image_conversion_lot1\image00005.jpg
# Saved E:\image_conversion_lot1\image00005.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00005.tiff in 300 DPI
#
#
#
#
#
#
# Processing 8 of 54
# E:\image_conversion_lot1\image00006.jpg
# Saved E:\image_conversion_lot1\image00006.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00006.tiff in 300 DPI
#
#
#
#
#
#
# Processing 9 of 54
# E:\image_conversion_lot1\image00007.jpg
# Saved E:\image_conversion_lot1\image00007.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00007.tiff in 300 DPI
#
#
#
#
#
#
# Processing 10 of 54
# E:\image_conversion_lot1\image00008.jpg
# Saved E:\image_conversion_lot1\image00008.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00008.tiff in 300 DPI
#
#
#
#
#
#
# Processing 11 of 54
# E:\image_conversion_lot1\image00009.jpg
# Saved E:\image_conversion_lot1\image00009.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00009.tiff in 300 DPI
#
#
#
#
#
#
# Processing 12 of 54
# E:\image_conversion_lot1\image00010.jpg
# Saved E:\image_conversion_lot1\image00010.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00010.tiff in 300 DPI
#
#
#
#
#
#
# Processing 13 of 54
# E:\image_conversion_lot1\image00011.jpg
# Saved E:\image_conversion_lot1\image00011.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00011.tiff in 300 DPI
#
#
#
#
#
#
# Processing 14 of 54
# E:\image_conversion_lot1\image00012.jpg
# Saved E:\image_conversion_lot1\image00012.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00012.tiff in 300 DPI
#
#
#
#
#
#
# Processing 15 of 54
# E:\image_conversion_lot1\image00013.jpg
# Saved E:\image_conversion_lot1\image00013.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00013.tiff in 300 DPI
#
#
#
#
#
#
# Processing 16 of 54
# E:\image_conversion_lot1\image00014.jpg
# Saved E:\image_conversion_lot1\image00014.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00014.tiff in 300 DPI
#
#
#
#
#
#
# Processing 17 of 54
# E:\image_conversion_lot1\image00015.jpg
# Saved E:\image_conversion_lot1\image00015.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00015.tiff in 300 DPI
#
#
#
#
#
#
# Processing 18 of 54
# E:\image_conversion_lot1\image00016.jpg
# Saved E:\image_conversion_lot1\image00016.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00016.tiff in 300 DPI
#
#
#
#
#
#
# Processing 19 of 54
# E:\image_conversion_lot1\image00017.jpg
# Saved E:\image_conversion_lot1\image00017.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00017.tiff in 300 DPI
#
#
#
#
#
#
# Processing 20 of 54
# E:\image_conversion_lot1\image00018.jpg
# Saved E:\image_conversion_lot1\image00018.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00018.tiff in 300 DPI
#
#
#
#
#
#
# Processing 21 of 54
# E:\image_conversion_lot1\image00019.jpg
# Saved E:\image_conversion_lot1\image00019.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00019.tiff in 300 DPI
#
#
#
#
#
#
# Processing 22 of 54
# E:\image_conversion_lot1\image00020.jpg
# Saved E:\image_conversion_lot1\image00020.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00020.tiff in 300 DPI
#
#
#
#
#
#
# Processing 23 of 54
# E:\image_conversion_lot1\image00021.jpg
# Saved E:\image_conversion_lot1\image00021.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00021.tiff in 300 DPI
#
#
#
#
#
#
# Processing 24 of 54
# E:\image_conversion_lot1\image00022.jpg
# Saved E:\image_conversion_lot1\image00022.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00022.tiff in 300 DPI
#
#
#
#
#
#
# Processing 25 of 54
# E:\image_conversion_lot1\image00023.jpg
# Saved E:\image_conversion_lot1\image00023.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00023.tiff in 300 DPI
#
#
#
#
#
#
# Processing 26 of 54
# E:\image_conversion_lot1\image00024.jpg
# Saved E:\image_conversion_lot1\image00024.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00024.tiff in 300 DPI
#
#
#
#
#
#
# Processing 27 of 54
# E:\image_conversion_lot1\image00025.jpg
# Saved E:\image_conversion_lot1\image00025.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00025.tiff in 300 DPI
#
#
#
#
#
#
# Processing 28 of 54
# E:\image_conversion_lot1\image00026.jpg
# Saved E:\image_conversion_lot1\image00026.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00026.tiff in 300 DPI
#
#
#
#
#
#
# Processing 29 of 54
# E:\image_conversion_lot1\image00027.jpg
# Saved E:\image_conversion_lot1\image00027.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00027.tiff in 300 DPI
#
#
#
#
#
#
# Processing 30 of 54
# E:\image_conversion_lot1\image00028.jpg
# Saved E:\image_conversion_lot1\image00028.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00028.tiff in 300 DPI
#
#
#
#
#
#
# Processing 31 of 54
# E:\image_conversion_lot1\image00029.jpg
# Saved E:\image_conversion_lot1\image00029.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00029.tiff in 300 DPI
#
#
#
#
#
#
# Processing 32 of 54
# E:\image_conversion_lot1\image00030.jpg
# Saved E:\image_conversion_lot1\image00030.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00030.tiff in 300 DPI
#
#
#
#
#
#
# Processing 33 of 54
# E:\image_conversion_lot1\image00031.jpg
# Saved E:\image_conversion_lot1\image00031.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00031.tiff in 300 DPI
#
#
#
#
#
#
# Processing 34 of 54
# E:\image_conversion_lot1\image00032.jpg
# Saved E:\image_conversion_lot1\image00032.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00032.tiff in 300 DPI
#
#
#
#
#
#
# Processing 35 of 54
# E:\image_conversion_lot1\image00033.jpg
# Saved E:\image_conversion_lot1\image00033.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00033.tiff in 300 DPI
#
#
#
#
#
#
# Processing 36 of 54
# E:\image_conversion_lot1\image00034.jpg
# Saved E:\image_conversion_lot1\image00034.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00034.tiff in 300 DPI
#
#
#
#
#
#
# Processing 37 of 54
# E:\image_conversion_lot1\image00035.jpg
# Saved E:\image_conversion_lot1\image00035.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00035.tiff in 300 DPI
#
#
#
#
#
#
# Processing 38 of 54
# E:\image_conversion_lot1\image00036.jpg
# Saved E:\image_conversion_lot1\image00036.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00036.tiff in 300 DPI
#
#
#
#
#
#
# Processing 39 of 54
# E:\image_conversion_lot1\image00037.jpg
# Saved E:\image_conversion_lot1\image00037.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00037.tiff in 300 DPI
#
#
#
#
#
#
# Processing 40 of 54
# E:\image_conversion_lot1\image00038.jpg
# Saved E:\image_conversion_lot1\image00038.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00038.tiff in 300 DPI
#
#
#
#
#
#
# Processing 41 of 54
# E:\image_conversion_lot1\image00039.jpg
# Saved E:\image_conversion_lot1\image00039.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00039.tiff in 300 DPI
#
#
#
#
#
#
# Processing 42 of 54
# E:\image_conversion_lot1\image00040.jpg
# Saved E:\image_conversion_lot1\image00040.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00040.tiff in 300 DPI
#
#
#
#
#
#
# Processing 43 of 54
# E:\image_conversion_lot1\image00041.jpg
# Saved E:\image_conversion_lot1\image00041.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00041.tiff in 300 DPI
#
#
#
#
#
#
# Processing 44 of 54
# E:\image_conversion_lot1\image00042.jpg
# Saved E:\image_conversion_lot1\image00042.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00042.tiff in 300 DPI
#
#
#
#
#
#
# Processing 45 of 54
# E:\image_conversion_lot1\image00043.jpg
# Saved E:\image_conversion_lot1\image00043.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00043.tiff in 300 DPI
#
#
#
#
#
#
# Processing 46 of 54
# E:\image_conversion_lot1\image00044.jpg
# Saved E:\image_conversion_lot1\image00044.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00044.tiff in 300 DPI
#
#
#
#
#
#
# Processing 47 of 54
# E:\image_conversion_lot1\image00045.jpg
# Saved E:\image_conversion_lot1\image00045.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00045.tiff in 300 DPI
#
#
#
#
#
#
# Processing 48 of 54
# E:\image_conversion_lot1\image00046.jpg
# Saved E:\image_conversion_lot1\image00046.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00046.tiff in 300 DPI
#
#
#
#
#
#
# Processing 49 of 54
# E:\image_conversion_lot1\image00047.jpg
# Saved E:\image_conversion_lot1\image00047.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00047.tiff in 300 DPI
#
#
#
#
#
#
# Processing 50 of 54
# E:\image_conversion_lot1\image00048.jpg
# Saved E:\image_conversion_lot1\image00048.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00048.tiff in 300 DPI
#
#
#
#
#
#
# Processing 51 of 54
# E:\image_conversion_lot1\image00049.jpg
# Saved E:\image_conversion_lot1\image00049.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00049.tiff in 300 DPI
#
#
#
#
#
#
# Processing 52 of 54
# E:\image_conversion_lot1\image00050.jpg
# Saved E:\image_conversion_lot1\image00050.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00050.tiff in 300 DPI
#
#
#
#
#
#
# Processing 53 of 54
# E:\image_conversion_lot1\image00051.jpg
# Saved E:\image_conversion_lot1\image00051.pdf in 50 DPI
# Saved E:\image_conversion_lot1\image00051.tiff in 300 DPI
#
#
#
#
#
#
# Processing 54 of 54
# E:\image_conversion_lot1\Z.jpg
# Saved E:\image_conversion_lot1\Z.pdf in 50 DPI
# Saved E:\image_conversion_lot1\Z.tiff in 300 DPI

# %%
ex = ''
while ex.upper() != 'Q':
    ex = input("Press Q to exit : ")
# Out:
# Press Q to exita
# Press Q to exita
# Press Q to exita
# Press Q to exita
# Press Q to exitq
